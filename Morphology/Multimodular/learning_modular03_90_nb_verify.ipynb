# %%
import os, sys, math, pickle, time
from zmqRemoteApi import RemoteAPIClient
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from random import randint as ri
from random import uniform as ru

from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.losses import Huber
from keras.optimizers import Adam, SGD, RMSprop

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Funciones

# %%
#Function to split the training data into X,y datasets
def load_dataset(scene_in = "modular02a", date = "2023_21_12"):
    # Defining usefull variables
    path = os.getcwd() + "\\training\\training_data\\" + date
    file_list = os.listdir(path)
    scene_files_list = [item for item in file_list if scene_in in item and "pkl" in item]

    print(scene_files_list[0])
    file = open(path + "\\" + scene_files_list[0], "rb")
    training_data = pickle.load(file)
    training_df = pd.DataFrame(training_data)

    #List to store the name for every joint data column
    increments_columns = []
    prev_j_positions_columns = []
    post_j_positions_columns = []

    #Creates the name for every column
    num_joints = len(training_data[-1]["increments"])
    for joint_n in range(num_joints):
        #List to split inputs per joint
        joint_inc_col_name = "increments_" + str(joint_n)
        increments_columns.append(joint_inc_col_name)

        prev_joint_pos_col_name = "prev_j_positions_" + str(joint_n)
        prev_j_positions_columns.append(prev_joint_pos_col_name)

        #List to split outputs per joint
        post_joint_pos_col_name = "post_j_positions_" + str(joint_n)
        post_j_positions_columns.append(post_joint_pos_col_name)


    #Input columns per joint
    increments_df = pd.DataFrame(training_df['increments'].to_list())
    increments_df.columns = increments_columns


    prev_j_positions_df = pd.DataFrame(training_df['prev_j_positions'].to_list())
    prev_j_positions_df.columns = prev_j_positions_columns


    #Builds the X dataframe
    X_df = pd.concat([increments_df, prev_j_positions_df, 
                    training_df["prev_pos_x"], training_df["prev_pos_y"], training_df["prev_pos_z"]], 
                    axis="columns")


    #Output columns per joint
    post_j_positions_df = pd.DataFrame(training_df['post_j_positions'].to_list())
    post_j_positions_df.columns = post_j_positions_columns


    #Builds the y dataframe
    y_df = pd.concat([post_j_positions_df, 
                    training_df["post_pos_x"], training_df["post_pos_y"], training_df["post_pos_z"]], 
                    axis="columns")

    return(X_df,y_df)

# %%
def adapt_X_y(X_a,y_a):
    X_a_cols = ['current_state_x', 'current_state_y', 'current_state_z', 'joint0_current_state_rad', 'joint1_current_state_rad', 'joint2_current_state_rad'
                , 'joint0_actions_rad', 'joint1_actions_rad', 'joint2_actions_rad']

    X_a = pd.concat([X_a["prev_pos_x"], X_a["prev_pos_y"] , X_a["prev_pos_z"],
                X_a["prev_j_positions_0"], X_a["prev_j_positions_1"], X_a["prev_j_positions_2"],
                X_a["increments_0"], X_a["increments_1"], X_a["increments_2"]], 
                        axis="columns")

    X_a.columns = X_a_cols

    y_a_cols = ['future_state_x', 'future_state_y', 'future_state_z', 'joint0_future_state_rad', 'joint1_future_state_rad', 'joint2_future_state_rad']

    y_a = pd.concat([y_a["post_pos_x"], y_a["post_pos_y"] , y_a["post_pos_z"],
                y_a["post_j_positions_0"], y_a["post_j_positions_1"], y_a["post_j_positions_2"]], 
                        axis="columns")
    y_a.columns = y_a_cols
    return X_a, y_a

# %%
def plot_history(history, loss):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel(f'{loss} Loss')
  plt.plot(hist['epoch'], hist['loss'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_loss'],
           label = 'Val Error')
  plt.legend()
  plt.show()

# %%
def plot_history_short(history, loss):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel(f'{loss} Loss')
  plt.plot(hist['epoch'][19:], hist['loss'][19:],
           label='Train Error')
  plt.plot(hist['epoch'][19:], hist['val_loss'][19:],
           label = 'Val Error')
  plt.legend()
  plt.show()

# %%
def plot_pred_vs_test(test, pred):
    columns = test.columns.tolist()
    max_list = []
    min_list = []
    mse_list = []
    perc_mse_list = []
    for column_num in range(len(columns)):
        plt.figure()
        plt.scatter(test.iloc[:,column_num], pred.iloc[:,column_num], s=1, color = "red")

        #Getting important values
        minim = min(test.iloc[:,column_num])
        min_list.append(minim)
        maxim = max(test.iloc[:,column_num])
        max_list.append(maxim)
        mse = mean_squared_error(test.iloc[:,column_num], pred.iloc[:,column_num])
        mse_list.append(round(mse,6))
        rang = (maxim-minim)
        perc = mse/rang *100
        perc_mse_list.append(round(perc,6))
        title = columns[column_num] + " - mse: " + str(round(mse,6))
        plt.title(title)
        plt.xlabel('True Values')
        plt.ylabel('Predictions')
        # Para tener una linea recta con la cual comparar los valores y que no altere
        # los limites de la figura se grafican los valores reales con ellos mismos
        plt.plot(test.iloc[:,column_num],test.iloc[:,column_num])
        plt.grid()
    data = {"Perception": columns, "Max.": max_list, "Min.": min_list, "Mse": mse_list, "Mse perc.": perc_mse_list}
    data_df = pd.DataFrame(data)
    return(data_df)

# %%
# Grafica en español y unidades en ejes
def plot_pred_vs_test_clean(test, pred):
    columns = pred.columns.tolist()
    units = ["(m)", "(m)", "(m)", "(rad)", "(rad)", "(rad)"]
    max_list = []
    min_list = []
    mse_list = []
    perc_mse_list = []
    result = []
    for column_num in range(len(columns)):
        plt.figure()
        plt.scatter(test.iloc[:,column_num], pred.iloc[:,column_num], s=1, color = "red")

        #Getting important values
        minim = min(test.iloc[:,column_num])
        min_list.append(minim)
        maxim = max(test.iloc[:,column_num])
        max_list.append(maxim)
        mse = mean_squared_error(test.iloc[:,column_num], pred.iloc[:,column_num])
        mse_list.append(round(mse,6))
        rang = (maxim-minim)
        perc = mse/rang *100
        perc_mse_list.append(round(perc,6))
        if round(perc,3) <= 0.005:
            result.append(True)
        else:
            result.append(False)
        title = columns[column_num]
        plt.title(title)
        plt.xlabel('Valores reales ' + units[column_num])
        plt.ylabel('Predicción '+ units[column_num])
        # Para tener una linea recta con la cual comparar los valores y que no altere
        # los limites de la figura se grafican los valores reales con ellos mismos
        plt.plot(test.iloc[:,column_num],test.iloc[:,column_num])
        plt.grid()
    data = {"Percepción": columns, "Max.": max_list, "Min.": min_list, "Mse": mse_list, "Mse perc.": perc_mse_list, "Objective: ": result}
    data_df = pd.DataFrame(data)
    return(data_df)

# %%
def export_model(exp_scene, exp_model, exp_scaler):
    timestr = time.strftime("_%Y_%d_%m")
    models_path = "models\\" + timestr[1:]
    if not os.path.exists(models_path):
        os.mkdir(models_path)
        print(f"Directorio '{models_path}' ha sido creado.")
    else:
        print(f"El directorio '{models_path}' ya existe.")
    exp_model.save(models_path + "\\model_" + exp_scene + timestr + ".keras")
    with open(models_path + "\\model_" + exp_scene + timestr + '.pkl', 'wb') as file:
        pickle.dump(exp_model, file)
    with open(models_path + "\\scaler_" + exp_scene + timestr + '.pkl', 'wb') as file:
        pickle.dump(exp_scaler, file)

# %% [markdown]
# ### Modular03 90

# %%
scene = "modular03e"
date = "2024_23_01"
X, y =load_dataset(scene,date)
X, y = adapt_X_y(X,y)
X
# Out:
# joined_training_dataset_modular03e_2024_23_01_1023.pkl
#        current_state_x  current_state_y  current_state_z  \
# 0             0.000003         0.079223         0.233636
# 1             0.011429         0.076958         0.225945
# 2             0.105485         0.075939         0.114439
# 3             0.100989         0.063621         0.138157
# 4             0.070319         0.055100         0.193515
# ...                ...              ...              ...
# 99995         0.066504         0.095374         0.202667
# 99996         0.080490         0.059108         0.187428
# 99997         0.055831         0.058973         0.188630
# 99998         0.078403         0.052965         0.142664
# 99999         0.107317         0.075093         0.127476
#
#        joint0_current_state_rad  joint1_current_state_rad  \
# 0                     -0.000021                  0.000827
# 1                     -0.328087                  0.105341
# 2                     -1.571230                 -0.214643
# 3                     -1.570905                  0.869586
# 4                     -0.814466                  1.569136
# ...                         ...                       ...
# 99995                 -0.721418                  1.568816
# 99996                 -0.926142                  1.569404
# 99997                 -0.998795                  0.725774
# 99998                 -1.571152                  0.996143
# 99999                 -1.571306                  1.061973
#
#        joint2_current_state_rad  joint0_actions_rad  joint1_actions_rad  \
# 0                     -0.000417           -0.325596            0.104872
# 1                      0.818045           -1.370127           -0.313777
# 2                     -0.357342           -1.043699            1.067884
# 3                      0.682192            0.773436            1.504887
# 4                      0.860909           -0.494829            1.381509
# ...                         ...                 ...                 ...
# 99995                 -0.642285           -0.196411            0.686721
# 99996                  0.671979           -0.064740           -0.857205
# 99997                  1.483767           -0.761751            0.262365
# 99998                  1.562041           -0.393834            0.053007
# 99999                  0.098315            0.522744            0.065142
#
#        joint2_actions_rad
# 0                0.832749
# 1               -1.176847
# 2                1.056863
# 3                0.193696
# 4                0.040455
# ...                   ...
# 99995            1.309580
# 99996            0.796356
# 99997            1.428006
# 99998           -1.479718
# 99999           -0.384227
#
# [100000 rows x 9 columns]

# %%
# Se separan los datos de entrenmiento (80%) y los de prueba (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.15, random_state=42
)

print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (85000, 9) (15000, 9)
# (85000, 6) (15000, 6)

# %%
# Scaling de los datos 
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled.shape
# Out:
# (85000, 9)

# %% [markdown]
# Correr de aqui para arriba y luego donde dice correr

# %% [markdown]
# #### Combinaciones (se selecciona la 3H) (no correr)

# %% [markdown]
# Guardar los datos de cada combinacion

# %%
combination_data = []

# %%
c1 ={"num": "1","capas": 1, "neuronas": 9, "taza": 0.001, "epochs": 30, "batch": 20}
c2 ={"num": "2","capas": 3, "neuronas": 27, "taza": 0.4, "epochs": 50, "batch": 32}
c3 ={"num": "3","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 50, "batch": 32} # Se crea una combinacion mejorada para probar llamada 3

# Combinacion de hiperparametros numericos
c_num = c3

# Definicion de parametros numericos
capas = c_num["capas"]
neurons = c_num["neuronas"]
lr = c_num["taza"]
epochs_f = c_num["epochs"]
b_s = c_num["batch"]


cA ={"letter": "A", "activ": "linear", "optim": Adam(learning_rate=lr), "loss": Huber()}
cB ={"letter": "B", "activ": "sigmoid", "optim": SGD(learning_rate=lr), "loss": 'mean_squared_error'}
cC ={"letter": "C", "activ": "sigmoid", "optim": RMSprop(learning_rate=lr), "loss": 'mean_absolute_error'}
cD ={"letter": "D", "activ": "tanh", "optim": SGD(learning_rate=lr), "loss": Huber()}
cE ={"letter": "E", "activ": "tanh", "optim": Adam(learning_rate=lr), "loss": 'mean_squared_error'}
cF ={"letter": "F", "activ": "relu", "optim": RMSprop(learning_rate=lr), "loss": 'mean_squared_error'}
cG ={"letter": "G", "activ": "relu", "optim": Adam(learning_rate=lr), "loss": Huber()}

cH ={"letter": "H", "activ": "tanh", "optim": Adam(learning_rate=lr), "loss": Huber()} # Se ajustan las mejores combinaciones para buscar la definitiva
cI ={"letter": "I", "activ": "relu", "optim": Adam(learning_rate=lr), "loss": 'mean_squared_error'}


# Combinacion de hiperparametros cualitativos
c_cual = cI

# Definicion de parametros cualitativos
activation_f = c_cual["activ"]
optim = c_cual["optim"]
loss_f = c_cual["loss"]

c_data = []
combinacion = c_num["num"] + c_cual["letter"]
c_data.append(combinacion)

print("Combinacion: ",combinacion)

#Imprimir Hiperparametros
num_params = list(c_num.keys())
num_params_val = list(c_num.values())
for i in range(len(num_params)):
    llave = num_params[i]
    valor = num_params_val[i]
    print(llave)
    print("----------- "+ str(valor))

cual_params = list(c_cual.keys())
cual_params_val = list(c_cual.values())
for i in range(len(cual_params)):
    llave = cual_params[i]
    valor = cual_params_val[i]
    print(llave)
    print("----------- "+ str(valor))
# Out:
# Combinacion:  3I
# num
# ----------- 3
# capas
# ----------- 3
# neuronas
# ----------- 27
# taza
# ----------- 0.001
# epochs
# ----------- 50
# batch
# ----------- 32
# letter
# ----------- I
# activ
# ----------- relu
# optim
# ----------- <keras.src.optimizers.adam.Adam object at 0x0000025DBBA75ED0>
# loss
# ----------- mean_squared_error

# %% [markdown]
# Dependiendo de la combinacion se crea la red

# %%
print("Combinacion: ",combinacion)
model = Sequential()

# Capa de entrada con 22 unidades (correspondiente al número de entradas)
model.add(Dense(units=9, input_dim=9, activation=activation_f))

for layers in range(capas):
    # Capas ocultas
    model.add(Dense(units=neurons, activation=activation_f))

# Capa de salida con 14 unidades (correspondiente al número de salidas) y activación lineal
model.add(Dense(units=6, activation='linear'))

# Compilar el modelo con una función de pérdida adecuada para regresión
model.compile(optimizer=optim, loss=loss_f)

# Supongamos que X_train y y_train son tus datos de entrenamiento
history = model.fit(X_train_scaled, y_train, epochs=epochs_f, batch_size=b_s, validation_split=0.17)
# Out:
# Combinacion:  3I
# Epoch 1/50
# 2646/2646 [==============================] - 5s 1ms/step - loss: 0.0356 - val_loss: 0.0024
# Epoch 2/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 3/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 7.4990e-04 - val_loss: 4.4434e-04
# Epoch 4/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 4.1188e-04 - val_loss: 2.9167e-04
# Epoch 5/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 3.0106e-04 - val_loss: 3.8632e-04
# Epoch 6/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 2.5442e-04 - val_loss: 2.4766e-04
# Epoch 7/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 2.2977e-04 - val_loss: 2.1095e-04
# Epoch 8/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 2.0773e-04 - val_loss: 1.7731e-04
# Epoch 9/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.9557e-04 - val_loss: 1.8114e-04
# Epoch 10/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.8570e-04 - val_loss: 1.4307e-04
# Epoch 11/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.7406e-04 - val_loss: 2.7167e-04
# Epoch 12/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.7139e-04 - val_loss: 2.2613e-04
# Epoch 13/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.7170e-04 - val_loss: 2.0188e-04
# Epoch 14/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.6323e-04 - val_loss: 1.8053e-04
# Epoch 15/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.6101e-04 - val_loss: 1.2453e-04
# Epoch 16/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.5799e-04 - val_loss: 2.1700e-04
# Epoch 17/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.5528e-04 - val_loss: 1.2454e-04
# Epoch 18/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.4827e-04 - val_loss: 1.3827e-04
# Epoch 19/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.4203e-04 - val_loss: 1.8297e-04
# Epoch 20/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.4466e-04 - val_loss: 1.1158e-04
# Epoch 21/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.4256e-04 - val_loss: 1.2060e-04
# Epoch 22/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.3608e-04 - val_loss: 1.4824e-04
# Epoch 23/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.3321e-04 - val_loss: 1.2471e-04
# Epoch 24/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2631e-04 - val_loss: 9.1917e-05
# Epoch 25/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2541e-04 - val_loss: 1.3191e-04
# Epoch 26/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2366e-04 - val_loss: 1.1637e-04
# Epoch 27/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2006e-04 - val_loss: 1.4215e-04
# Epoch 28/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2129e-04 - val_loss: 1.0582e-04
# Epoch 29/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2012e-04 - val_loss: 1.0955e-04
# Epoch 30/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1804e-04 - val_loss: 1.2162e-04
# Epoch 31/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.2013e-04 - val_loss: 1.4976e-04
# Epoch 32/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1638e-04 - val_loss: 8.8470e-05
# Epoch 33/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1771e-04 - val_loss: 9.0585e-05
# Epoch 34/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1751e-04 - val_loss: 1.1608e-04
# Epoch 35/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1926e-04 - val_loss: 1.2453e-04
# Epoch 36/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1221e-04 - val_loss: 9.5811e-05
# Epoch 37/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1343e-04 - val_loss: 1.0265e-04
# Epoch 38/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1502e-04 - val_loss: 8.9620e-05
# Epoch 39/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1343e-04 - val_loss: 9.7584e-05
# Epoch 40/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1357e-04 - val_loss: 1.2492e-04
# Epoch 41/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1172e-04 - val_loss: 1.1730e-04
# Epoch 42/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1081e-04 - val_loss: 1.4415e-04
# Epoch 43/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.0881e-04 - val_loss: 9.2388e-05
# Epoch 44/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1033e-04 - val_loss: 1.0982e-04
# Epoch 45/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1136e-04 - val_loss: 9.0808e-05
# Epoch 46/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.1025e-04 - val_loss: 1.0031e-04
# Epoch 47/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.0998e-04 - val_loss: 1.4403e-04
# Epoch 48/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.0750e-04 - val_loss: 1.3862e-04
# Epoch 49/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.0723e-04 - val_loss: 8.6781e-05
# Epoch 50/50
# 2646/2646 [==============================] - 3s 1ms/step - loss: 1.0921e-04 - val_loss: 1.2118e-04

# %%
print("Combinacion: ",combinacion)
print(len(list(model.layers))-2)
#plot_history(history, "Huber")
plot_history(history, loss_f)
# Out:
# Combinacion:  3I
# 3

# %%
print("Combinacion:", combinacion)
## Finalmente se hace uso de los datos de prueba para la predicción.
plot_cols = ["Posición en X", "Posición en Y", "Posición en Z", "Posición articulación 1", "Posición articulación 2", "Posición articulación 3"]
test_predictions = model.predict(X_test_scaled)
df_test_predictions = pd.DataFrame(test_predictions)
df_test_predictions.columns = plot_cols
plot_pred_vs_test_clean(y_test, df_test_predictions)
# Out:
# Combinacion: 3I
# 563/563 [==============================] - 1s 841us/step
#                 Percepción      Max.      Min.       Mse  Mse perc.  \
# 0            Posición en X  0.185825 -0.185979  0.000056   0.015139
# 1            Posición en Y  0.000035 -0.000089  0.000000   0.150797
# 2            Posición en Z  0.311982  0.018482  0.000094   0.032045
# 3  Posición articulación 1  1.570895 -1.570961  0.000306   0.009741
# 4  Posición articulación 2  1.570797 -1.570798  0.000167   0.005302
# 5  Posición articulación 3  1.570797 -1.570798  0.000111   0.003523
#
#    Objective:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5         True

# %% [markdown]
# #### Exportar (no correr)

# %%
scene_name = scene + "_capasocultas_neuronascapa1_activacioncapa1__neuronascapa_n_activacioncapa1_n_optimizador_learningrate_perdida_epochs_batch_"
export_model(scene_name, model, scaler)

# %% [markdown]
# ### Optimizacion de modelo 3H (correr esto)

# %%
c3 ={"num": "3","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 50, "batch": 32} # Se crea una combinacion mejorada para probar llamada 3
c4 ={"num": "4","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 100, "batch": 21} # Se crea una combinacion mejorada para probar llamada 4
c5 ={"num": "5","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 500, "batch": 42} # Se crea una combinacion mejorada para probar llamada 4
c6 ={"num": "6","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 500, "batch": 21}
c7 ={"num": "7","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 100, "batch": 42}
c8 ={"num": "8","capas": 3, "neuronas": 36, "taza": 0.001, "epochs": 500, "batch": 21}

c6p ={"num": "6+","capas": 3, "neuronas": 27, "taza": 0.001, "epochs": 750, "batch": 21}
c8p ={"num": "8+","capas": 3, "neuronas": 36, "taza": 0.001, "epochs": 750, "batch": 21}

# Combinacion de hiperparametros numericos
c_num_opt = c5

# Definicion de parametros numericos
capas = c_num_opt["capas"]
neurons = c_num_opt["neuronas"]
lr = c_num_opt["taza"]
epochs_f = c_num_opt["epochs"]
b_s = c_num_opt["batch"]

cE ={"letter": "E", "activ": "tanh", "optim": Adam(learning_rate=lr), "loss": 'mean_squared_error'}
cH ={"letter": "H", "activ": "tanh", "optim": Adam(learning_rate=lr), "loss": Huber()} # Se ajustan las mejores combinaciones para buscar la definitiva

# Combinacion de hiperparametros cualitativos
c_cual_opt = cH

# Definicion de parametros cualitativos
activation_f = c_cual_opt["activ"]
optim = c_cual_opt["optim"]
loss_f = c_cual_opt["loss"]

combinacion_opt = c_num_opt["num"] + c_cual_opt["letter"]
print("Combinacion por optimizar: " + combinacion_opt)

#Imprimir Hiperparametros
num_params = list(c_num_opt.keys())
num_params_val = list(c_num_opt.values())
for i in range(len(num_params)):
    llave = num_params[i]
    valor = num_params_val[i]
    print(llave)
    print("----------- "+ str(valor))

cual_params = list(c_cual_opt.keys())
cual_params_val = list(c_cual_opt.values())
for i in range(len(cual_params)):
    llave = cual_params[i]
    valor = cual_params_val[i]
    print(llave)
    print("----------- "+ str(valor))

v_split = 0.17
print ("Val. split :", v_split)
# Out:
# Combinacion por optimizar: 5H
# num
# ----------- 5
# capas
# ----------- 3
# neuronas
# ----------- 27
# taza
# ----------- 0.001
# epochs
# ----------- 500
# batch
# ----------- 42
# letter
# ----------- H
# activ
# ----------- tanh
# optim
# ----------- <keras.src.optimizers.adam.Adam object at 0x0000024AC5BD9510>
# loss
# ----------- <keras.src.losses.Huber object at 0x0000024AC6284350>
# Val. split : 0.17

# %%
print("Combinacion por optimizar: " + combinacion_opt)
model = Sequential()

# Capa de entrada con 22 unidades (correspondiente al número de entradas)
model.add(Dense(units=9, input_dim=9, activation=activation_f))

for layers in range(capas):
    # Capas ocultas
    model.add(Dense(units=neurons, activation=activation_f))

# Capa de salida con 14 unidades (correspondiente al número de salidas) y activación lineal
model.add(Dense(units=6, activation='linear'))

# Compilar el modelo con una función de pérdida adecuada para regresión
model.compile(optimizer=optim, loss=loss_f)

# Supongamos que X_train y y_train son tus datos de entrenamiento
history = model.fit(X_train_scaled, y_train, epochs=epochs_f, batch_size=b_s, validation_split=v_split)
# Out:
# Combinacion por optimizar: 5H
# Epoch 1/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 0.0171 - val_loss: 0.0025
# Epoch 2/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 3/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 4/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 5/500
# 1680/1680 [==============================] - 3s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 6/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 7/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 8/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.4196e-04 - val_loss: 8.5521e-04
# Epoch 9/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 7.0982e-04 - val_loss: 5.5901e-04
# Epoch 10/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 4.5174e-04 - val_loss: 3.8074e-04
# Epoch 11/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.7379e-04 - val_loss: 3.1940e-04
# Epoch 12/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.3699e-04 - val_loss: 3.2932e-04
# Epoch 13/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.1824e-04 - val_loss: 3.4147e-04
# Epoch 14/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 2.8853e-04 - val_loss: 3.2828e-04
# Epoch 15/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 2.5235e-04 - val_loss: 2.1708e-04
# Epoch 16/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 2.2052e-04 - val_loss: 2.0169e-04
# Epoch 17/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 1.9488e-04 - val_loss: 1.6678e-04
# Epoch 18/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.8079e-04 - val_loss: 1.6762e-04
# Epoch 19/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.7222e-04 - val_loss: 1.7861e-04
# Epoch 20/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.6454e-04 - val_loss: 1.4436e-04
# Epoch 21/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.5858e-04 - val_loss: 1.4252e-04
# Epoch 22/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.5614e-04 - val_loss: 1.6528e-04
# Epoch 23/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 1.5097e-04 - val_loss: 1.5337e-04
# Epoch 24/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.4424e-04 - val_loss: 1.4969e-04
# Epoch 25/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.4143e-04 - val_loss: 2.0361e-04
# Epoch 26/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.3858e-04 - val_loss: 1.2193e-04
# Epoch 27/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.3459e-04 - val_loss: 1.2721e-04
# Epoch 28/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.3318e-04 - val_loss: 1.1962e-04
# Epoch 29/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.3009e-04 - val_loss: 1.3216e-04
# Epoch 30/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.2876e-04 - val_loss: 1.3419e-04
# Epoch 31/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.2590e-04 - val_loss: 1.1775e-04
# Epoch 32/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.2378e-04 - val_loss: 1.0400e-04
# Epoch 33/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.2156e-04 - val_loss: 1.1659e-04
# Epoch 34/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.2228e-04 - val_loss: 1.3037e-04
# Epoch 35/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1986e-04 - val_loss: 1.1651e-04
# Epoch 36/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1505e-04 - val_loss: 1.1719e-04
# Epoch 37/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1551e-04 - val_loss: 1.1173e-04
# Epoch 38/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1241e-04 - val_loss: 1.3032e-04
# Epoch 39/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1262e-04 - val_loss: 1.2931e-04
# Epoch 40/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.1029e-04 - val_loss: 9.4161e-05
# Epoch 41/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.0764e-04 - val_loss: 1.0166e-04
# Epoch 42/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.0676e-04 - val_loss: 9.5406e-05
# Epoch 43/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 1.0536e-04 - val_loss: 1.2774e-04
# Epoch 44/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.0107e-04 - val_loss: 8.7393e-05
# Epoch 45/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 1.0254e-04 - val_loss: 9.9433e-05
# Epoch 46/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.8783e-05 - val_loss: 9.1576e-05
# Epoch 47/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.6946e-05 - val_loss: 1.1594e-04
# Epoch 48/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.4661e-05 - val_loss: 1.4892e-04
# Epoch 49/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.1937e-05 - val_loss: 8.7341e-05
# Epoch 50/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 9.0546e-05 - val_loss: 9.0696e-05
# Epoch 51/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.9452e-05 - val_loss: 8.4138e-05
# Epoch 52/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.5494e-05 - val_loss: 8.4296e-05
# Epoch 53/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.4857e-05 - val_loss: 7.7401e-05
# Epoch 54/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.3869e-05 - val_loss: 1.1228e-04
# Epoch 55/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.3707e-05 - val_loss: 7.1990e-05
# Epoch 56/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 8.0879e-05 - val_loss: 8.8268e-05
# Epoch 57/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 7.9935e-05 - val_loss: 7.6901e-05
# Epoch 58/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 7.6726e-05 - val_loss: 6.8629e-05
# Epoch 59/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 7.5985e-05 - val_loss: 6.8838e-05
# Epoch 60/500
# 1680/1680 [==============================] - 3s 2ms/step - loss: 7.5201e-05 - val_loss: 7.3350e-05
# Epoch 61/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 7.0977e-05 - val_loss: 9.6692e-05
# Epoch 62/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.9355e-05 - val_loss: 6.1959e-05
# Epoch 63/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.7974e-05 - val_loss: 6.2453e-05
# Epoch 64/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.6206e-05 - val_loss: 6.4441e-05
# Epoch 65/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.3824e-05 - val_loss: 7.4747e-05
# Epoch 66/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.3336e-05 - val_loss: 5.4534e-05
# Epoch 67/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.1977e-05 - val_loss: 6.7859e-05
# Epoch 68/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.3479e-05 - val_loss: 7.1411e-05
# Epoch 69/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.8649e-05 - val_loss: 6.7580e-05
# Epoch 70/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 6.0114e-05 - val_loss: 6.0997e-05
# Epoch 71/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.8721e-05 - val_loss: 6.2110e-05
# Epoch 72/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.8164e-05 - val_loss: 7.2671e-05
# Epoch 73/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.6591e-05 - val_loss: 7.3144e-05
# Epoch 74/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.7753e-05 - val_loss: 5.8354e-05
# Epoch 75/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.5394e-05 - val_loss: 5.6221e-05
# Epoch 76/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.4767e-05 - val_loss: 7.1251e-05
# Epoch 77/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 5.3302e-05 - val_loss: 5.4112e-05
# Epoch 78/500
# 1680/1680 [==============================] - 2s 1ms/step - loss:
500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5910e-05 - val_loss: 4.0396e-05
# Epoch 477/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5821e-05 - val_loss: 3.1463e-05
# Epoch 478/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6339e-05 - val_loss: 2.9510e-05
# Epoch 479/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6095e-05 - val_loss: 4.4700e-05
# Epoch 480/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5791e-05 - val_loss: 3.7527e-05
# Epoch 481/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6542e-05 - val_loss: 3.4265e-05
# Epoch 482/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5818e-05 - val_loss: 3.5099e-05
# Epoch 483/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6053e-05 - val_loss: 4.2788e-05
# Epoch 484/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6312e-05 - val_loss: 3.6589e-05
# Epoch 485/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6500e-05 - val_loss: 3.3246e-05
# Epoch 486/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5570e-05 - val_loss: 4.9521e-05
# Epoch 487/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6458e-05 - val_loss: 3.1159e-05
# Epoch 488/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6050e-05 - val_loss: 3.8349e-05
# Epoch 489/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6315e-05 - val_loss: 3.6979e-05
# Epoch 490/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6100e-05 - val_loss: 2.8834e-05
# Epoch 491/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6418e-05 - val_loss: 3.6733e-05
# Epoch 492/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6678e-05 - val_loss: 4.0389e-05
# Epoch 493/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5683e-05 - val_loss: 3.8420e-05
# Epoch 494/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6249e-05 - val_loss: 3.6632e-05
# Epoch 495/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6968e-05 - val_loss: 4.1381e-05
# Epoch 496/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.5452e-05 - val_loss: 3.5543e-05
# Epoch 497/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6413e-05 - val_loss: 4.2634e-05
# Epoch 498/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.4883e-05 - val_loss: 4.4505e-05
# Epoch 499/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6529e-05 - val_loss: 4.8903e-05
# Epoch 500/500
# 1680/1680 [==============================] - 2s 1ms/step - loss: 3.6473e-05 - val_loss: 3.1822e-05

# %%
print("Combinacion por optimizar: " + combinacion_opt)
print(len(list(model.layers))-2)
plot_history_short(history, "Huber")
# Out:
# Combinacion por optimizar: 5H
# 3

# %%
print("Combinacion por optimizar: " + combinacion_opt)
## Finalmente se hace uso de los datos de prueba para la predicción.
plot_cols = ["Posición en X", "Posición en Y", "Posición en Z", "Posición articulación 1", "Posición articulación 2", "Posición articulación 3"]
test_predictions = model.predict(X_test_scaled)
df_test_predictions = pd.DataFrame(test_predictions)
df_test_predictions.columns = plot_cols
plot_pred_vs_test_clean(y_test, df_test_predictions)
# Out:
# Combinacion por optimizar: 5H
# 469/469 [==============================] - 0s 857us/step
#                 Percepción      Max.      Min.       Mse  Mse perc.  \
# 0            Posición en X  0.107583 -0.107536  0.000004   0.001715
# 1            Posición en Y  0.107208  0.047261  0.000003   0.005211
# 2            Posición en Z  0.233631  0.095641  0.000003   0.002306
# 3  Posición articulación 1  1.574655 -1.573281  0.000120   0.003807
# 4  Posición articulación 2  1.580678 -1.580961  0.000139   0.004394
# 5  Posición articulación 3  1.575952 -1.575485  0.000123   0.003895
#
#    Objective:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True

# %%
os.startfile("decidemp3-14575.mp3")

# %% [markdown]
# Para exportar

# %%
rep = 1

# %%
export_model(scene + "_5H_4_", model, scaler)
rep = rep +1
# Out:
# Directorio 'models\2024_24_01' ha sido creado.

# %% [markdown]
# ### Revision de datos (no hace falta correr)

# %%
columns = X_train.columns.tolist()
plt.figure()
plt.scatter(X.iloc[:,0],X.iloc[:,2], s=1, color='blue')
plt.scatter(X_train.iloc[:,0],X_train.iloc[:,2], s=1, color='green', label='Entrenamiento')
plt.scatter(X_test.iloc[:,0],X_test.iloc[:,2], s=1, color='red', label='Validacion')
plt.title(" X vs Z 90")
plt.ylabel(columns[2])
plt.xlabel(columns[0])
plt.legend()
plt.grid()

# %%
columns = X_train.columns.tolist()
plt.figure()
plt.scatter(X.iloc[:,0],X.iloc[:,1], s=1, color='blue')
plt.scatter(X_train.iloc[:,0],X_train.iloc[:,1], s=1, color='green', label='Entrenamiento')
plt.scatter(X_test.iloc[:,0],X_test.iloc[:,1], s=1, color='red', label='Validacion')
plt.title(" X vs Y")
plt.ylabel(columns[1])
plt.xlabel(columns[0])
plt.legend()
plt.grid()

# %%
columns = X_train.columns.tolist()
plt.figure()
plt.scatter(X.iloc[:,1],X.iloc[:,2], s=1, color='blue')
plt.scatter(X_train.iloc[:,1],X_train.iloc[:,2], s=1, color='green', label='Entrenamiento')
plt.scatter(X_test.iloc[:,1],X_test.iloc[:,2], s=1, color='red', label='Validacion')
plt.title(" Y vs Z 90")
plt.ylabel(columns[2])
plt.xlabel(columns[0])
plt.legend()
plt.grid()

# %% [markdown]
# #### Grafica 3D

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Datos de ejemplo
x = X.iloc[:,0]
y = X.iloc[:,1]
z = X.iloc[:,2]

# Crear una figura en 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar puntos en 3D
ax.scatter(x, y, z, c='r', marker='o')

# Etiquetas de ejes
ax.set_xlabel('Eje X (m)')
ax.set_ylabel('Eje Y (m)')
ax.set_zlabel('Eje Z (m)')

# Mostrar la gráfica en 3D
fig.set_size_inches(8, 8)
plt.show()

# %% [markdown]
# #### Combinaciones de posiciones e incrementos

# %%
columns = X_train.columns.tolist()
joints_col = []
for col in columns:
    if "joint" in col:
        joints_col.append(col)
joints_col
joints_n = len(joints_col)//2
for joint in range(joints_n):
    plt.figure()
    state_col = 3 + joint
    act_col = 3 + joint + joints_n
    plt.scatter(X.iloc[:,state_col],X.iloc[:,act_col], s=1, color='blue')
    plt.scatter(X_train.iloc[:,state_col],X_train.iloc[:,act_col], s=1, color='green', label='Entrenamiento')
    plt.scatter(X_test.iloc[:,state_col],X_test.iloc[:,act_col], s=1, color='red', label='Validacion')
    plt.title(f" {columns[state_col]} vs {columns[act_col]}")
    plt.ylabel(columns[act_col])
    plt.xlabel(columns[state_col])
    plt.legend()
    plt.grid()

# %%
neurons = 18
epochs_f = 40
b_s = 32

# Activacion
activation_f = 'linear'
#activation_f = 'sigmoid'
#activation_f = 'tanh'
#activation_f = 'ReLU'

# Optimizador
#optim = SDG(learning_rate=0.001)
#optim = RMSprop(learning_rate=0.001)
optim = Adam(learning_rate=0.001)

# Funcion de perdida
#loss_f = 'mean_squared_error'
#loss_f = 'mean_absolute_error'
loss_f = Huber()

# %%
model = Sequential()

# Capa de entrada con 22 unidades (correspondiente al número de entradas)
model.add(Dense(units=9, input_dim=9))

# Capas ocultas con 64 unidades cada una
model.add(Dense(units=neurons, activation=activation_f))

# Capa de salida con 14 unidades (correspondiente al número de salidas) y activación lineal
model.add(Dense(units=6, activation='linear'))

# Compilar el modelo con una función de pérdida adecuada para regresión
model.compile(optimizer=optim, loss=loss_f)

# Supongamos que X_train y y_train son tus datos de entrenamiento
history = model.fit(X_train_scaled, y_train, epochs=epochs_f, batch_size=b_s, validation_split=0.2)
# Out:
# Epoch 1/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0354 - val_loss: 0.0182
# Epoch 2/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0182 - val_loss: 0.0181
# Epoch 3/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 4/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0181 - val_loss: 0.0180
# Epoch 5/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0181 - val_loss: 0.0180
# Epoch 6/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0183
# Epoch 7/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 8/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0183
# Epoch 9/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 10/40
# 2400/2400 [==============================] - 4s 1ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 11/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0180 - val_loss: 0.0182
# Epoch 12/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0180 - val_loss: 0.0183
# Epoch 13/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 14/40
# 2400/2400 [==============================] - 4s 1ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 15/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 16/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 17/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 18/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 19/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 20/40
# 2400/2400 [==============================] - 7s 3ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 21/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 22/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 23/40
# 2400/2400 [==============================] - 4s 1ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 24/40
# 2400/2400 [==============================] - 4s 1ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 25/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0183
# Epoch 26/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0183
# Epoch 27/40
# 2400/2400 [==============================] - 4s 1ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 28/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0180 - val_loss: 0.0180
# Epoch 29/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 30/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 31/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0182
# Epoch 32/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 33/40
# 2400/2400 [==============================] - 3s 1ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 34/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 35/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 36/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 37/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 38/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 39/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0182
# Epoch 40/40
# 2400/2400 [==============================] - 4s 2ms/step - loss: 0.0179 - val_loss: 0.0180

# %%
plot_history(history, "Huber")

# %%
## Finalmente se hace uso de los datos de prueba para la predicción.
test_predictions = model.predict(X_test_scaled)
df_test_predictions = pd.DataFrame(test_predictions)
df_test_predictions.columns = y_test.columns
plot_pred_vs_test(y_test, df_test_predictions)
# Out:
# 750/750 [==============================] - 1s 795us/step
#                 Perception      Max.      Min.       Mse  Mse perc.
# 0           future_state_x  0.185844 -0.185979  0.003050   0.820327
# 1           future_state_y  0.000035 -0.000089  0.000001   0.660248
# 2           future_state_z  0.312063  0.018482  0.005299   1.804885
# 3  joint0_future_state_rad  1.570902 -1.570961  0.070500   2.243906
# 4  joint1_future_state_rad  1.570797 -1.570798  0.070139   2.232599
# 5  joint2_future_state_rad  1.570797 -1.570798  0.066998   2.132622
